# %%
import numpy as np
import csv

data=[]

with open('../../tests/accelfile.txt', 'r') as f:
    spamreader = csv.reader(f, delimiter=' ')
    for row in spamreader:
        myrow=[]
        try:
            for x in row:            
                if x != '':
                    xf=float(x)                                
                    myrow.append(float(x))        
            data.append(myrow)            
        except:
            ...
        
data_downsampled=[]
for i in range(len(data)):  
    if i%10==0:
        data_downsampled.append(data[i])
    
data=np.array(data)    
data_downsampled=np.array(data_downsampled)

# %%
from matplotlib import pyplot as plt

names=["timestamp","mag_x","mag_y","mag_z","accel_x","accel_y","accel_z","gyro_x","gyro_y","gyro_z"]

for i in range(len(data[0])):
    fig, ax = plt.subplots()
    plt.title(names[i])
    plt.xlim(8,10)
    plt.plot(data[:,0]-data[0,0],data[:,i],'*')
    plt.plot(data_downsampled[:,0]-data_downsampled[0,0],data_downsampled[:,i],'*')
    plt.show()
