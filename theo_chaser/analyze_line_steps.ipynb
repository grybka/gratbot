# %%
import csv
import numpy as np

bm_time=[]
bm_b=[]
bm_m=[]
with open("line_follow_log_20201120-163149.txt ") as f:
    reader=csv.reader(f,delimiter=' ')
    for row in reader:
        bm_time.append(float(row[0]))
        bm_b.append(float(row[1])/100)
        bm_m.append(float(row[2]))
f.close()
bm_time=np.array(bm_time)
bm_b=np.array(bm_b)
bm_m=np.array(bm_m)

action_time=[]
action_fb=[]
action_skew=[]
action_turn=[]
with open("line_follow_action_log_20201120-163149.txt") as f:
    reader=csv.reader(f,delimiter=' ')
    for row in reader:
        action_time.append(float(row[0]))
        action_fb.append(10*float(row[1])*float(row[4]))
        action_skew.append(10*float(row[2])*float(row[4]))
        action_turn.append(10*float(row[3])*float(row[4]))
f.close()

action_time=np.array(action_time)
action_fb=np.array(action_fb)
action_skew=np.array(action_skew)
action_turn=np.array(action_turn)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.plot(bm_time,bm_b)
ax.set(xlabel='time (s)', ylabel='',title='b')
fig.show()
fig, ax = plt.subplots()
ax.set(xlabel='time (s)', ylabel='',title='m')
ax.plot(bm_time,bm_m)
fig.show()

fig, ax = plt.subplots()
ax.set(xlabel='time (s)', ylabel='',title='skew')
ax.plot(action_time,action_skew)
fig.show()
fig, ax = plt.subplots()
ax.set(xlabel='time (s)', ylabel='',title='turn')
ax.plot(action_time,action_turn)
fig.show()
fig, ax = plt.subplots()
ax.set(xlabel='time (s)', ylabel='',title='fb')
ax.plot(action_time,action_fb)
fig.show()
# Out:
# <ipython-input-2-17a61326c9b1>:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-2-17a61326c9b1>:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-2-17a61326c9b1>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-2-17a61326c9b1>:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-2-17a61326c9b1>:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
before_time_indices=np.searchsorted(bm_time,action_time)-1
after_time_indices=np.searchsorted(bm_time,action_time+0.3)
delta_t=bm_time[after_time_indices]-bm_time[before_time_indices]
fig, ax = plt.subplots()
ax.set(xlabel='number', ylabel='deltat',title='deltat')
ax.plot(np.linspace(0,1,len(delta_t)),delta_t)
fig.show()

#TODO CUT certain indices
before_time_indices=before_time_indices[delta_t<1.0]
after_time_indices=after_time_indices[delta_t<1.0]
print(delta_t)
print(action_skew)
action_skew=action_skew[delta_t<1.0]
action_turn=action_turn[delta_t<1.0]
action_fb=action_fb[delta_t<1.0]
delta_t=delta_t[delta_t<1.0]
fig, ax = plt.subplots()
ax.set(xlabel='number', ylabel='deltat',title='deltat')
ax.plot(np.linspace(0,1,len(delta_t)),delta_t)
fig.show()
# Out:
# [0.5395577  0.52958322 0.54454303 0.52359986 0.5116303  0.5331769
#  0.54055429 0.51960969 0.5435071  0.52263904 0.52160478 0.51964664
#  0.54254842 0.52059984 0.52556396 0.528265   0.53463531 0.52157712
#  0.51770473 0.52858829 0.53656483 0.53658175 0.52064466 0.51951146
#  0.53158021 0.53254747 0.52362728 0.52357221 0.5265944  0.55451798
#  0.51958251 0.51960874 0.52858663 0.5246017  0.54055429 0.52262974
#  0.53559256 0.53058124 0.54454494 0.52359676 0.53955698 0.52160549
#  0.54254866 0.52659249 0.54653835 0.53753281 0.52263904 0.65627337
#  0.48769641 0.52060342 0.53858685 0.53552794 0.54354668 0.53253913
#  0.53955746 0.54255795 0.53560305 0.52759027 0.52562308 0.54454422
#  0.57443619 0.54258513 0.54155183 0.52656484 0.51960921 0.53759027
#  0.53057289 0.5166173  0.53556705 0.53955674 0.54155183 0.53653717
#  0.52357173 0.54155159 0.54053712 0.52580214 0.55460429 6.42905498
#  0.52659273 0.52661872 7.14104414 0.52474976 0.52555847 0.60538197
#  0.53060937 0.57346582 0.53058124 0.52758813 0.54055476 0.52659059
#  0.52359962 0.5445435  0.53058219 0.52559543 5.10758662 0.52559447
#  0.54756379 0.52256727 0.52858591 0.5814147  0.54254913 0.53157711
#  0.53556824 0.48171139]
# [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   4.03884547e-05 -1.00586318e-01 -3.11049344e-01  2.44273041e-01
#   1.69177325e-01 -4.47388913e-01 -4.65295466e-01  1.31153176e-01
#  -3.68259529e-01  4.30794747e-01 -3.15387299e-01  3.20707353e-01
#  -4.54825878e-01  4.90456336e-01  9.59750612e-02  1.51005801e-01
#   7.19658334e-02 -2.09407652e-01 -3.71523574e-01 -3.06571225e-01
#   4.67159134e-01 -4.49408580e-01 -1.37758977e-01 -4.87189230e-01
#   3.13597356e-01  4.52559671e-01 -2.22659038e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
# <ipython-input-3-3d17e61651ac>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-3-3d17e61651ac>:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dm=bm_m[after_time_indices]-bm_m[before_time_indices]
db=bm_b[after_time_indices]-bm_b[before_time_indices]
am_m=bm_m[before_time_indices]
am_b=bm_b[before_time_indices]

skew_elem=np.nonzero(action_skew)
turn_elem=np.nonzero(action_turn)
fb_elem=np.nonzero(action_fb)


fig, ax = plt.subplots()
ax.plot(action_skew[skew_elem],db[skew_elem],'*')
ax.set(xlabel='skew', ylabel='db',title='')
fig.show()

fig, ax = plt.subplots()
ax.plot(action_skew,dm,'*')
ax.set(xlabel='skew', ylabel='dm',title='')
fig.show()

fig, ax = plt.subplots()
ax.plot(action_turn[turn_elem],db[turn_elem],'*')
ax.set(xlabel='turn', ylabel='db',title='')
fig.show()

fig, ax = plt.subplots()
ax.plot(action_turn[turn_elem],dm[turn_elem],'*')
ax.set(xlabel='turn', ylabel='dm',title='')
fig.show()

fb_elem=np.nonzero(action_fb)

fig, ax = plt.subplots()
ax.plot(action_fb[fb_elem],db[fb_elem],'*')
ax.set(xlabel='fb', ylabel='db',title='')
fig.show()

fig, ax = plt.subplots()
ax.plot(action_fb[fb_elem],dm[fb_elem],'*')
ax.set(xlabel='fb', ylabel='dm',title='nonzero')
fig.show()

fig, ax = plt.subplots()
ax.plot(action_fb[fb_elem],db[fb_elem]*am_m[fb_elem],'*')
ax.set(xlabel='fb', ylabel='db*b',title='')
fig.show()
# Out:
# <ipython-input-4-dd24191147e4>:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:19: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:29: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:36: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-4-dd24191147e4>:46: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import csv
import random
import numpy as np

skew_act_pred_model=nn.Sequential(nn.Linear(4,4),nn.Sigmoid(),nn.Linear(4,1))
#skew_bm_pred_model=nn.Sequential(nn.Linear(3,3),nn.Sigmoid(),nn.Linear(3,2))
skew_bm_pred_model=nn.Linear(3,2)
turn_act_pred_model=nn.Sequential(nn.Linear(4,4),nn.Sigmoid(),nn.Linear(4,1))
#turn_bm_pred_model=nn.Sequential(nn.Linear(3,3),nn.Sigmoid(),nn.Linear(3,2))
turn_bm_pred_model=nn.Linear(3,2)
fb_act_pred_model=nn.Sequential(nn.Linear(4,4),nn.Sigmoid(),nn.Linear(4,1))
fb_bm_pred_model=nn.Sequential(nn.Linear(3,3),nn.Sigmoid(),nn.Linear(3,2))
#fb_bm_pred_model=nn.Linear(3,2)

# %%
skew_act_pred_x=[]
skew_act_pred_y=[]
for i in range(len(skew_elem[0])):
    skew_act_pred_x.append(torch.tensor([db[skew_elem][i],dm[skew_elem][i],am_m[skew_elem][i],am_b[skew_elem][i]]))
    skew_act_pred_y.append(torch.tensor([action_skew[skew_elem][i]]))
skew_act_pred_x_t=torch.stack(skew_act_pred_x).float()
skew_act_pred_y_t=torch.stack(skew_act_pred_y).float() 


skew_train_x=[]
skew_train_y=[]
for i in range(len(skew_elem[0])):
    skew_train_x.append(torch.tensor([am_m[skew_elem][i],am_b[skew_elem][i],action_skew[skew_elem][i]]))
    skew_train_y.append(torch.tensor([dm[skew_elem][i],db[skew_elem][i]]))
skew_train_x_t=torch.stack(skew_train_x).float()
skew_train_y_t=torch.stack(skew_train_y).float()



print("skew act pred x size {}".format(skew_act_pred_x_t.size()))
print("skew act pred y size {}".format(skew_act_pred_y_t.size()))
# Out:
# skew act pred x size torch.Size([27, 4])
# skew act pred y size torch.Size([27, 1])

# %%
#train action predictor

def train_act_pred(relevant_elems,action_array,model,name='unknown',lr=0.01):
    #prep the data
    x=[]
    y=[]
    for i in range(len(relevant_elems[0])):
        x.append(torch.tensor([db[relevant_elems][i],dm[relevant_elems][i],am_m[relevant_elems][i],am_b[relevant_elems][i]]))
        y.append(torch.tensor([action_array[relevant_elems][i]]))
    x=torch.stack(x).float()
    y=torch.stack(y).float() 

    loss_fn=nn.MSELoss()
    optimizer = torch.optim.Adagrad(model.parameters(),lr=lr)

    entry=[]
    losslog=[]
    for i in range(30000):
        optimizer.zero_grad()
        y_pred=model(x)
        loss=loss_fn(y_pred,y)
        if i%1000==0 and i !=0:
    #if i%1==0:
            print("Trial {} Loss {}".format(i,loss.item()/len(relevant_elems[0])))
        if i%100==0 and i !=0:
            entry.append(i)
            losslog.append(loss.item()/len(relevant_elems[0]))
        loss.backward()
        optimizer.step()

    fig, ax = plt.subplots()
    ax.plot(entry,losslog)
    ax.set(xlabel='Step', ylabel='Loss',title='')
    fig.show()
    
    y_pred=model(x)
    fig, ax = plt.subplots()
    ax.plot(y,x[:,0],'*')
    ax.plot(y_pred.detach(),x[:,0],'*')
    ax.set(xlabel=name, ylabel='db',title='')
    fig.show()

    fig, ax = plt.subplots()
    ax.plot(y,x[:,1],'*')
    ax.plot(y_pred.detach(),x[:,1],'*')
    ax.set(xlabel=name, ylabel='dm',title='')
    fig.show()

# %%
train_act_pred(skew_elem,action_skew,skew_act_pred_model,'skew',0.01)
train_act_pred(turn_elem,action_turn,turn_act_pred_model,'turn',0.01)
train_act_pred(fb_elem,action_fb,fb_act_pred_model,'fb',0.01)
# Out:
# Trial 1000 Loss 0.0010224966401303256
# Trial 2000 Loss 0.00033932882878515456
# Trial 3000 Loss 0.0002307119537834768
# Trial 4000 Loss 0.00020348063359657922
# Trial 5000 Loss 0.0001895950969170641
# Trial 6000 Loss 0.00018097184322498464
# Trial 7000 Loss 0.00017537485325226076
# Trial 8000 Loss 0.00017164252629434622
# Trial 9000 Loss 0.0001690767843414236
# Trial 10000 Loss 0.00016724513153787012
# Trial 11000 Loss 0.00016587750158376165
# Trial 12000 Loss 0.00016480491117194847
# Trial 13000 Loss 0.00016392170693035478
# Trial 14000 Loss 0.00016316185118975463
# Trial 15000 Loss 0.00016248376212186285
# Trial 16000 Loss 0.00016186181110916314
# Trial 17000 Loss 0.00016127909637159773
# Trial 18000 Loss 0.0001607258045287044
# Trial 19000 Loss 0.00016019455398674364
# Trial 20000 Loss 0.00015968170568898872
# Trial 21000 Loss 0.00015918318941085427
# Trial 22000 Loss 0.0001586977806356218
# Trial 23000 Loss 0.00015822413411957246
# Trial 24000 Loss 0.00015776088737227297
# Trial 25000 Loss 0.00015730679863029055
# Trial 26000 Loss 0.00015686193688048256
# Trial 27000 Loss 0.0001564259571885621
# Trial 28000 Loss 0.00015599725561009513
# Trial 29000 Loss 0.00015557638403994065
# <ipython-input-7-6f21e67b3ada>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Trial 1000 Loss 0.00035809148819400714
# Trial 2000 Loss 0.0003143921494483948
# Trial 3000 Loss 0.0002930732981230204
# Trial 4000 Loss 0.0002703344485221001
# Trial 5000 Loss 0.0002474450828650823
# Trial 6000 Loss 0.00022613455971273093
# Trial 7000 Loss 0.00020830315322830126
# Trial 8000 Loss 0.0001945990460136762
# Trial 9000 Loss 0.00018398488800113017
# Trial 10000 Loss 0.0001751041362205377
# Trial 11000 Loss 0.00016711516162523857
# Trial 12000 Loss 0.0001596304623839947
# Trial 13000 Loss 0.00015248766598793177
# Trial 14000 Loss 0.00014562490217101114
# Trial 15000 Loss 0.00013904841258548773
# Trial 16000 Loss 0.00013283058069646358
# Trial 17000 Loss 0.00012709934694262652
# Trial 18000 Loss 0.00012199227841427692
# Trial 19000 Loss 0.00011759886267380073
# Trial 20000 Loss 0.00011392912934892453
# Trial 21000 Loss 0.00011092067087212435
# Trial 22000 Loss 0.00010846614336165098
# Trial 23000 Loss 0.00010644703601988462
# Trial 24000 Loss 0.00010475324681745126
# Trial 25000 Loss 0.0001032949837211233
# Trial 26000 Loss 0.00010200417958773099
# Trial 27000 Loss 0.00010083193998210705
# Trial 28000 Loss 9.974544473852102e-05
# Trial 29000 Loss 9.872233316015739e-05
# <ipython-input-7-6f21e67b3ada>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Trial 1000 Loss 0.0014060488902032375
# Trial 2000 Loss 0.0013382954833408196
# Trial 3000 Loss 0.0012914351342866819
# Trial 4000 Loss 0.0012494003555426996
# Trial 5000 Loss 0.0012088501825928688
# Trial 6000 Loss 0.0011688917875289917
# Trial 7000 Loss 0.0011291357222944498
# Trial 8000 Loss 0.0010893008826921384
# Trial 9000 Loss 0.0010482222617914279
# Trial 10000 Loss 0.0010026045298824708
# Trial 11000 Loss 0.0009493429679423571
# Trial 12000 Loss 0.0008917704690247774
# Trial 13000 Loss 0.000836813123896718
# Trial 14000 Loss 0.0007891020892808834
# Trial 15000 Loss 0.0007501059056570133
# Trial 16000 Loss 0.0007196965161710978
# Trial 17000 Loss 0.0006968626597275337
# Trial 18000 Loss 0.000680069982384642
# Trial 19000 Loss 0.0006677459459751844
# Trial 20000 Loss 0.0006585676067819198
# Trial 21000 Loss 0.0006515123726179203
# Trial 22000 Loss 0.0006458044905836383
# Trial 23000 Loss 0.0006408336339518428
# Trial 24000 Loss 0.000636081793345511
# Trial 25000 Loss 0.0006310899819557866
# Trial 26000 Loss 0.0006255183446531495
# Trial 27000 Loss 0.0006193116617699465
# Trial 28000 Loss 0.000612767762504518
# Trial 29000 Loss 0.0006063187417263786
# <ipython-input-7-6f21e67b3ada>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-7-6f21e67b3ada>:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#train future predictor

def train_future_predictor(relevant_elems,action_array,model,name='unknown',lr=0.01):
    
    x=[]
    y=[]
    for i in range(len(relevant_elems[0])):
        x.append(torch.tensor([am_b[relevant_elems][i],am_m[relevant_elems][i],action_array[relevant_elems][i]]))
        y.append(torch.tensor([db[relevant_elems][i],dm[relevant_elems][i]]))
        
    x=torch.stack(x).float()
    y=torch.stack(y).float()     
    
    loss_fn=nn.MSELoss()
    optimizer = torch.optim.Adagrad(model.parameters(),lr=lr)

    entry=[]
    losslog=[]
    for i in range(150000):
        optimizer.zero_grad()
        y_pred=model(x)
        loss=loss_fn(y_pred,y)
        if i%1000==0 and i !=0:    
            print("Trial {} Loss {}".format(i,loss.item()/len(relevant_elems[0])))
        if i%100==0 and i !=0:    
            entry.append(i)
            losslog.append(loss.item()/len(relevant_elems[0]))    
        loss.backward()
        optimizer.step()

    fig, ax = plt.subplots()
    ax.plot(entry,losslog)
    ax.set(xlabel='Step', ylabel='Loss',title='')
    fig.show()
                               
    y_pred=model(x)
    fig, ax = plt.subplots()
    ax.plot(x[:,2],y[:,0],'*')
    ax.plot(x[:,2],y_pred.detach()[:,0],'*')
    ax.set(xlabel=name, ylabel='db',title='')
    fig.show()

    fig, ax = plt.subplots()
    ax.plot(x[:,2],y[:,1],'*')
    ax.plot(x[:,2],y_pred.detach()[:,1],'*')
    ax.set(xlabel=name, ylabel='db',title='')
    fig.show()

# %%
train_future_predictor(skew_elem,action_skew,skew_bm_pred_model,name='skew',lr=0.01)
train_future_predictor(turn_elem,action_turn,turn_bm_pred_model,name='turn',lr=0.01)
train_future_predictor(fb_elem,action_fb,fb_bm_pred_model,name='fb',lr=0.01)
# Out:
# Trial 1000 Loss 0.0024978653700263413
# Trial 2000 Loss 0.0012302825020419227
# Trial 3000 Loss 0.0008781092862288157
# Trial 4000 Loss 0.0006844671098170457
# Trial 5000 Loss 0.0005663313937407953
# Trial 6000 Loss 0.0004905775810281435
# Trial 7000 Loss 0.0004398020812206798
# Trial 8000 Loss 0.00040422190256692746
# Trial 9000 Loss 0.0003781358676928061
# Trial 10000 Loss 0.0003581393027195224
# Trial 11000 Loss 0.00034216153262941925
# Trial 12000 Loss 0.0003289235755801201
# Trial 13000 Loss 0.0003176224935385916
# Trial 14000 Loss 0.0003077461625690813
# Trial 15000 Loss 0.0002989605138147319
# Trial 16000 Loss 0.00029104244377877977
# Trial 17000 Loss 0.00028383809452255565
# Trial 18000 Loss 0.0002772376389691123
# Trial 19000 Loss 0.0002711605004690312
# Trial 20000 Loss 0.0002655447805645289
# Trial 21000 Loss 0.0002603412398861514
# Trial 22000 Loss 0.000255509124447902
# Trial 23000 Loss 0.00025101482040352293
# Trial 24000 Loss 0.00024682890485834194
# Trial 25000 Loss 0.0002429262493495588
# Trial 26000 Loss 0.00023928382951352332
# Trial 27000 Loss 0.00023588193235573945
# Trial 28000 Loss 0.0002327019314247149
# Trial 29000 Loss 0.00022972766654910865
# Trial 30000 Loss 0.00022694416758086946
# Trial 31000 Loss 0.0002243382235368093
# Trial 32000 Loss 0.0002218968303943122
# Trial 33000 Loss 0.0002196084328547672
# Trial 34000 Loss 0.00021746309681071175
# Trial 35000 Loss 0.0002154506639473968
# Trial 36000 Loss 0.00021356221771350614
# Trial 37000 Loss 0.00021179022129487108
# Trial 38000 Loss 0.0002101263272817488
# Trial 39000 Loss 0.00020856353350811533
# Trial 40000 Loss 0.00020709587261080742
# Trial 41000 Loss 0.0002057162044500863
# Trial 42000 Loss 0.0002044203553210806
# Trial 43000 Loss 0.0002032017024854819
# Trial 44000 Loss 0.0002020563481858483
# Trial 45000 Loss 0.00020097920464144813
# Trial 46000 Loss 0.00019996566697955132
# Trial 47000 Loss 0.0001990130447127201
# Trial 48000 Loss 0.00019811659499450966
# Trial 49000 Loss 0.0001972729547156228
# Trial 50000 Loss 0.0001964793816484787
# Trial 51000 Loss 0.00019573268515092355
# Trial 52000 Loss 0.0001950297780610897
# Trial 53000 Loss 0.0001943678491645389
# Trial 54000 Loss 0.00019374486334897852
# Trial 55000 Loss 0.00019315887173568762
# Trial 56000 Loss 0.00019260695962994187
# Trial 57000 Loss 0.0001920873506201638
# Trial 58000 Loss 0.00019159794060720337
# Trial 113000 Loss 0.000994734036234709
# Trial 114000 Loss 0.000994734036234709
# Trial 115000 Loss 0.000994734179515105
# Trial 116000 Loss 0.0009947339645945109
# Trial 117000 Loss 0.0009947339645945109
# Trial 118000 Loss 0.0009947339645945109
# Trial 119000 Loss 0.0009947339645945109
# Trial 120000 Loss 0.0009947339645945109
# Trial 121000 Loss 0.0009947339645945109
# Trial 122000 Loss 0.0009947338929543127
# Trial 123000 Loss 0.0009947338929543127
# Trial 124000 Loss 0.0009947338929543127
# Trial 125000 Loss 0.0009947338929543127
# Trial 126000 Loss 0.0009947338213141148
# Trial 127000 Loss 0.0009947338213141148
# Trial 128000 Loss 0.0009947338929543127
# Trial 129000 Loss 0.0009947339645945109
# Trial 130000 Loss 0.0009947338929543127
# Trial 131000 Loss 0.0009947339645945109
# Trial 132000 Loss 0.0009947339645945109
# Trial 133000 Loss 0.0009947338213141148
# Trial 134000 Loss 0.0009947338929543127
# Trial 135000 Loss 0.0009947337496739167
# Trial 136000 Loss 0.0009947339645945109
# Trial 137000 Loss 0.0009947338929543127
# Trial 138000 Loss 0.0009947339645945109
# Trial 139000 Loss 0.0009947338929543127
# Trial 140000 Loss 0.0009947339645945109
# Trial 141000 Loss 0.0009947339645945109
# Trial 142000 Loss 0.0009947338213141148
# Trial 143000 Loss 0.0009947338213141148
# Trial 144000 Loss 0.0009947338929543127
# Trial 145000 Loss 0.0009947338213141148
# Trial 146000 Loss 0.0009947338213141148
# Trial 147000 Loss 0.0009947338929543127
# Trial 148000 Loss 0.0009947338213141148
# Trial 149000 Loss 0.0009947338213141148
# <ipython-input-9-a39861d96759>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-9-a39861d96759>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-9-a39861d96759>:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Trial 1000 Loss 0.00030816726696987945
# Trial 2000 Loss 0.0003037642066677411
# Trial 3000 Loss 0.00030092481756582856
# Trial 4000 Loss 0.00029844043698782724
# Trial 5000 Loss 0.00029616021007920307
# Trial 6000 Loss 0.00029402550232286256
# Trial 7000 Loss 0.00029200169956311584
# Trial 8000 Loss 0.0002900652859049539
# Trial 9000 Loss 0.0002881986244271199
# Trial 10000 Loss 0.00028638830796505016
# Trial 11000 Loss 0.00028462349049126107
# Trial 12000 Loss 0.00028289577070002753
# Trial 13000 Loss 0.000281198318892469
# Trial 14000 Loss 0.00027952562474335235
# Trial 15000 Loss 0.00027787405997514725
# Trial 16000 Loss 0.00027623991870010894
# Trial 17000 Loss 0.0002746214740909636
# Trial 18000 Loss 0.00027301604859530926
# Trial 19000 Loss 0.00027142340938250226
# Trial 20000 Loss 0.0002698428967657189
# Trial 21000 Loss 0.00026827369583770633
# Trial 22000 Loss 0.00026671580659846467
# Trial 23000 Loss 0.0002651703349935512
# Trial 24000 Loss 0.0002636363885054986
# Trial 25000 Loss 0.0002621162178305288
# Trial 26000 Loss 0.0002606083677771191
# Trial 27000 Loss 0.0002591149726261695
# Trial 28000 Loss 0.0002576364398313065
# Trial 29000 Loss 0.0002561729052104056
# Trial 30000 Loss 0.0002547241941404839
# Trial 31000 Loss 0.00025329209165647626
# Trial 32000 Loss 0.00025187710222477716
# Trial 33000 Loss 0.00025048060342669487
# Trial 34000 Loss 0.00024910218780860305
# Trial 35000 Loss 0.0002477413703066607
# Trial 36000 Loss 0.00024639898523067433
# Trial 37000 Loss 0.00024507650717472035
# Trial 38000 Loss 0.0002437723451294005
# Trial 39000 Loss 0.00024248838114241758
# Trial 40000 Loss 0.00024122343165799975
# Trial 41000 Loss 0.00023997784592211246
# Trial 42000 Loss 0.00023875220601136485
# Trial 43000 Loss 0.00023754670595129332
# Trial 44000 Loss 0.00023636105470359325
# Trial 45000 Loss 0.0002351953686835865
# Trial 46000 Loss 0.00023405003594234586
# Trial 47000 Loss 0.00023292499827221036
# Trial 48000 Loss 0.0002318201392578582
# Trial 49000 Loss 0.00023073522606864572
# Trial 50000 Loss 0.0002296701422892511
# Trial 51000 Loss 0.00022862502373754978
# Trial 52000 Loss 0.00022760041368504366
# Trial 53000 Loss 0.0002265951867836217
# Trial 54000 Loss 0.0002256094206434985
# Trial 55000 Loss 0.00022464398837958774
# Trial 56000 Loss 0.00022369778404633203
# Trial 57000 Loss 0.00022277135091523329
# Trial 58000 Loss 0.00022186338901519775
# Trial 59000 Loss 0.0002209754311479628
# Trial 60000 Loss 0.00022010629375775656
# Trial 61000 Loss 0.00021925640370075902
# Trial 62000 Loss 0.0002184248878620565
# Trial 63000 Loss 0.00021761157161866626
# Trial 64000 Loss 0.00021681589229653278
# Trial 65000 Loss 0.00021603914986674985
# Trial 66000 Loss 0.00021528008316333094
# Trial 67000 Loss 0.00021453830413520336
# Trial 68000 Loss 0.0002138135217440625
# Trial 69000 Loss 0.00021310583300267658
# Trial 70000 Loss 0.0002124154125340283
# Trial 71000 Loss 0.0002117412514053285
# Trial 72000 Loss 0.00021108346603189906
# Trial 73000 Loss 0.00021044182358309627
# Trial 74000 Loss 0.00020981591660529375
# Trial 75000 Loss 0.000209204968996346
# Trial 76000 Loss 0.00020860934940477213
# Trial 77000 Loss 0.00020802830113098025
# Trial 78000 Loss 0.0002074622898362577
# Trial 79000 Loss 0.0002069108304567635
# Trial 80000 Loss 0.00020637359314908585
# Trial 81000 Loss 0.00020585007344683012
# Trial 82000 Loss 0.00020533916540443897
# Trial 83000 Loss 0.00020484170333171883
# Trial 84000 Loss 0.00020435764842356244
# Trial 85000 Loss 0.0002038862439803779
# Trial 86000 Loss 0.00020342725717152158
# Trial 87000 Loss 0.000202979640259097
# Trial 88000 Loss 0.00020254366487885514
# Trial 89000 Loss 0.0002021199131074051
# Trial 90000 Loss 0.00020170745362217227
# Trial 91000 Loss 0.0002013052386852602
# Trial 92000 Loss 0.00020091404439881444
# Trial 93000 Loss 0.0002005330752581358
# Trial 94000 Loss 0.00020016283572961888
# Trial 95000 Loss 0.00019980231688047448
# Trial 96000 Loss 0.00019945165452857813
# Trial 97000 Loss 0.00019911018898710608
# Trial 98000 Loss 0.00019877825009947023
# Trial 99000 Loss 0.0001984551587762932
# Trial 100000 Loss 0.00019814019712309042
# Trial 101000 Loss 0.00019783516957735023
# Trial 102000 Loss 0.0001975372627687951
# Trial 103000 Loss 0.00019724740801999965
# Trial 104000 Loss 0.00019696675008162856
# Trial 105000 Loss 0.00019669171888381243
# Trial 106000 Loss 0.00019642619493727884
# Trial 107000 Loss 0.00019616715144366026
# Trial 108000 Loss 0.00019591499585658312
# Trial 109000 Loss 0.00019567009682456651
# Trial 110000 Loss 0.00019543142601226768
# Trial 111000 Loss 0.00019519995354736844
# Trial 112000 Loss 0.000194974224238346
# Trial 113000 Loss 0.00019475495597968498
# Trial 114000 Loss 0.0001945416054998835
# Trial 115000 Loss 0.000194334095188727
# Trial 116000 Loss 0.00019413195938492814
# Trial 117000 Loss 0.0001939356055421134
# Trial 118000 Loss 0.00019374487843985358
# Trial 119000 Loss 0.00019355888556068143
# Trial 120000 Loss 0.00019337834479908148
# Trial 121000 Loss 0.0001932021890146037
# Trial 122000 Loss 0.00019303152415280542
# Trial 123000 Loss 0.0001928645845813056
# Trial 124000 Loss 0.0001927034075682362
# Trial 125000 Loss 0.00019254578122248253
# Trial 126000 Loss 0.00019239252045129737
# Trial 127000 Loss 0.00019224362525468072
# Trial 128000 Loss 0.0001920978732717534
# Trial 129000 Loss 0.00019195739878341556
# Trial 130000 Loss 0.00019181960184747973
# Trial 131000 Loss 0.0001916859958631297
# Trial 132000 Loss 0.00019155619277929267
# Trial 133000 Loss 0.00019142889262487492
# Trial 134000 Loss 0.00019130632669354478
# Trial 135000 Loss 0.00019118605026354393
# Trial 136000 Loss 0.000191068723021696
# Trial 137000 Loss 0.00019095556732888022
# Trial 138000 Loss 0.0001908442354761064
# Trial 139000 Loss 0.0001907368229391674
# Trial 140000 Loss 0.0001906320103444159
# Trial 141000 Loss 0.00019052886636927724
# Trial 142000 Loss 0.00019042931186656156
# Trial 143000 Loss 0.0001903322796958188
# Trial 144000 Loss 0.00019023687733958164
# Trial 145000 Loss 0.00019014473461235562
# Trial 146000 Loss 0.000190055250034978
# Trial 147000 Loss 0.00018996718184401593
# Trial 148000 Loss 0.00018988120912884673
# Trial 149000 Loss 0.00018979837962736687
# <ipython-input-9-a39861d96759>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-9-a39861d96759>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-9-a39861d96759>:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#save models
#action prediction models.  Given [ db/100, dm, m, b/100] prection [ 10*action_scale ]
#future prediction models   Given [ b/100, m, 10*action_scale] predect next [ b/100, m]

# Specify a path to save to
PATH = "motion_pred.pt"

torch.save({
            'skew_act_pred_model': skew_act_pred_model.state_dict(),
            'turn_act_pred_model': turn_act_pred_model.state_dict(),           
            'fb_act_pred_model': fb_act_pred_model.state_dict(),           
            'skew_bm_pred_model': skew_bm_pred_model.state_dict(),           
            'turn_bm_pred_model': turn_bm_pred_model.state_dict(),           
            'fb_bm_pred_model': fb_bm_pred_model.state_dict(),           
            }, PATH)
